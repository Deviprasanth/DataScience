# %% [markdown]
# # Predicting Housing Prices

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Get Data

# %%
traindf = pd.read_csv('train.csv')

testdf = pd.read_csv('test.csv')

Combinedf = [traindf,testdf]
# For removal of same columns from both df at a same time in Data Cleansing

# %% [markdown]
# ## Analyse the Data

# %%
traindf.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#traindf.describe()

# %%
#traindf.columns.values

# %%
#traindf.info()
##For different datatypes of columns

# %%
traindf['MSSubClass'].astype('category').head()
# Out:
# 0    60
# 1    20
# 2    60
# 3    70
# 4    60
# Name: MSSubClass, dtype: category
# Categories (15, int64): [20, 30, 40, 45, ..., 120, 160, 180, 190]

# %% [markdown]
# ### Seperate Labels and Train Data

# %%
Y= traindf['SalePrice']
Y.head()
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
X=traindf.iloc[:,0:80]
X.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC Fence  \
# 0         Lvl    AllPub      ...                 0        0    NaN   NaN
# 1         Lvl    AllPub      ...                 0        0    NaN   NaN
# 2         Lvl    AllPub      ...                 0        0    NaN   NaN
# 3         Lvl    AllPub      ...                 0        0    NaN   NaN
# 4         Lvl    AllPub      ...                 0        0    NaN   NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %% [markdown]
# ## Preprocessing
#
# This has 2 steps (as of now)
# 1. Categrical to numerical vectors (get_dummies)
# 2. Handling missing values

# %%
pd.get_dummies(traindf.iloc[:,1:10]).head()
# Automatically Converts categorical Data to 0s and 1s
# Out:
#    MSSubClass  LotFrontage  LotArea  MSZoning_C (all)  MSZoning_FV  \
# 0          60         65.0     8450                 0            0
# 1          20         80.0     9600                 0            0
# 2          60         68.0    11250                 0            0
# 3          70         60.0     9550                 0            0
# 4          60         84.0    14260                 0            0
#
#    MSZoning_RH  MSZoning_RL  MSZoning_RM  Street_Grvl  Street_Pave  \
# 0            0            1            0            0            1
# 1            0            1            0            0            1
# 2            0            1            0            0            1
# 3            0            1            0            0            1
# 4            0            1            0            0            1
#
#          ...         LotShape_IR1  LotShape_IR2  LotShape_IR3  LotShape_Reg  \
# 0        ...                    0             0             0             1
# ...

# %% [markdown]
# ## Cleaning
